# %% [markdown]
# # NEF summary
#
# The Neural Engineering Framework (NEF)
# is one set of theoretical methods that are used in
# Nengo for constructing neural models.
# The NEF is based on [Eliasmith & Anderson's (2003) book](
# https://mitpress.mit.edu/books/neural-engineering) from MIT Press.
# This notebook introduces the three main principles
# discussed in that book and implemented in Nengo.

# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt

import nengo
from nengo.dists import Uniform
from nengo.processes import WhiteSignal
from nengo.utils.ensemble import tuning_curves
from nengo.utils.ipython import hide_input
from nengo.utils.matplotlib import rasterplot


def aligned(n_neurons, radius=0.9):
    intercepts = np.linspace(-radius, radius, n_neurons)
    encoders = np.tile([[1], [-1]], (n_neurons // 2, 1))
    intercepts *= encoders[:, 0]
    return intercepts, encoders


hide_input()
# Out:
#         <a id="1832110078" href="javascript:toggle_input_1832110078()"
#           >Show Input</a>
#
#         <script type="text/javascript">
#         var toggle_input_1832110078;
#         (function() {
#             if (typeof jQuery == 'undefined') {
#                 // no jQuery
#                 var link_1832110078 = document.getElementById("1832110078");
#                 var cell = link_1832110078;
#                 while (cell.className.split(' ')[0] != "cell"
#                        && cell.className.split(' ')[0] != "nboutput") {
#                     cell = cell.parentNode;
#                 }
#                 var input_1832110078;
#                 if (cell.className.split(' ')[0] == "cell") {
#                     for (var i = 0; i < cell.children.length; i++) {
#                         if (cell.children[i].className.split(' ')[0]
#                             == "input") {
#                             input_1832110078 = cell.children[i];
#                         }
#                     }
#                 } else {
#                     input_1832110078 = cell.previousElementSibling;
#                 }
#                 input_1832110078.style.display = "none"; // hide
#
#                 toggle_input_1832110078 = function() {
#                     if (input_1832110078.style.display == "none") {
#                         input_1832110078.style.display = ""; // show
#                         link_1832110078.innerHTML = "Hide Input";
#                     } else {
#                         input_1832110078.style.display = "none"; // hide
#                         link_1832110078.innerHTML = "Show Input";
#                     }
#                 }
#
#             } else {
#                 // jQuery
#                 var link_1832110078 = $("a[id='1832110078']");
#                 var cell_1832110078 = link_1832110078.parents("div.cell:first");
#                 if (cell_1832110078.length == 0) {
#                     cell_1832110078 = link_1832110078.parents(
#                         "div.nboutput:first");
#                 }
#                 var input_1832110078 = cell_1832110078.children("div.input");
#                 if (input_1832110078.length == 0) {
#                     input_1832110078 = cell_1832110078.prev("div.nbinput");
#                 }
#                 input_1832110078.hide();
#
#                 toggle_input_1832110078 = function() {
#                     if (input_1832110078.is(':hidden')) {
#                         input_1832110078.slideDown();
#                         link_1832110078[0].innerHTML = "Hide Input";
#                     } else {
#                         input_1832110078.slideUp();
#                         link_1832110078[0].innerHTML = "Show Input";
#                     }
#                 }
#             }
#         }());
#         </script>

# %% [markdown]
# ## Principle 1: Representation
#
# ### Encoding
#
# Neural populations represent time-varying signals
# through their spiking responses.
# A signal is a vector of real numbers of arbitrary length.
# This example is a 1D signal going from -1 to 1 in 1 second.

# %%
model = nengo.Network(label="NEF summary")
with model:
    input = nengo.Node(lambda t: t * 2 - 1)
    input_probe = nengo.Probe(input)

# %%
with nengo.Simulator(model) as sim:
    sim.run(1.0)

plt.figure()
plt.plot(sim.trange(), sim.data[input_probe], lw=2)
plt.title("Input signal")
plt.xlabel("Time (s)")
plt.xlim(0, 1);
hide_input()
# Out:
#         <a id="1399562291" href="javascript:toggle_input_1399562291()"
#           >Show Input</a>
#
#         <script type="text/javascript">
#         var toggle_input_1399562291;
#         (function() {
#             if (typeof jQuery == 'undefined') {
#                 // no jQuery
#                 var link_1399562291 = document.getElementById("1399562291");
#                 var cell = link_1399562291;
#                 while (cell.className.split(' ')[0] != "cell"
#                        && cell.className.split(' ')[0] != "nboutput") {
#                     cell = cell.parentNode;
#                 }
#                 var input_1399562291;
#                 if (cell.className.split(' ')[0] == "cell") {
#                     for (var i = 0; i < cell.children.length; i++) {
#                         if (cell.children[i].className.split(' ')[0]
#                             == "input") {
#                             input_1399562291 = cell.children[i];
#                         }
#                     }
#                 } else {
#                     input_1399562291 = cell.previousElementSibling;
#                 }
#                 input_1399562291.style.display = "none"; // hide
#
#                 toggle_input_1399562291 = function() {
#                     if (input_1399562291.style.display == "none") {
#                         input_1399562291.style.display = ""; // show
#                         link_1399562291.innerHTML = "Hide Input";
#                     } else {
#                         input_1399562291.style.display = "none"; // hide
#                         link_1399562291.innerHTML = "Show Input";
#                     }
#                 }
#
#             } else {
#                 // jQuery
#                 var link_1399562291 = $("a[id='1399562291']");
#                 var cell_1399562291 = link_1399562291.parents("div.cell:first");
#                 if (cell_1399562291.length == 0) {
#                     cell_1399562291 = link_1399562291.parents(
#                         "div.nboutput:first");
#                 }
#                 var input_1399562291 = cell_1399562291.children("div.input");
#                 if (input_1399562291.length == 0) {
#                     input_1399562291 = cell_1399562291.prev("div.nbinput");
#                 }
#                 input_1399562291.hide();
#
#                 toggle_input_1399562291 = function() {
#                     if (input_1399562291.is(':hidden')) {
#                         input_1399562291.slideDown();
#                         link_1399562291[0].innerHTML = "Hide Input";
#                     } else {
#                         input_1399562291.slideUp();
#                         link_1399562291[0].innerHTML = "Show Input";
#                     }
#                 }
#             }
#         }());
#         </script>

# %% [markdown]
# These signals drive neural populations
# based on each neuron's *tuning curve*
# (which is similar to the current-frequency curve,
# if you're familiar with that).
#
# The tuning curve describes how much
# a particular neuron will fire as a function of the input signal.

# %%
intercepts, encoders = aligned(8)  # Makes evenly spaced intercepts
with model:
    A = nengo.Ensemble(
        8,
        dimensions=1,
        intercepts=intercepts,
        max_rates=Uniform(80, 100),
        encoders=encoders)

# %%
with nengo.Simulator(model) as sim:
    eval_points, activities = tuning_curves(A, sim)

plt.figure()
plt.plot(eval_points, activities, lw=2)
plt.xlabel("Input signal")
plt.ylabel("Firing rate (Hz)");
hide_input()
# Out:
#         <a id="549621502" href="javascript:toggle_input_549621502()"
#           >Show Input</a>
#
#         <script type="text/javascript">
#         var toggle_input_549621502;
#         (function() {
#             if (typeof jQuery == 'undefined') {
#                 // no jQuery
#                 var link_549621502 = document.getElementById("549621502");
#                 var cell = link_549621502;
#                 while (cell.className.split(' ')[0] != "cell"
#                        && cell.className.split(' ')[0] != "nboutput") {
#                     cell = cell.parentNode;
#                 }
#                 var input_549621502;
#                 if (cell.className.split(' ')[0] == "cell") {
#                     for (var i = 0; i < cell.children.length; i++) {
#                         if (cell.children[i].className.split(' ')[0]
#                             == "input") {
#                             input_549621502 = cell.children[i];
#                         }
#                     }
#                 } else {
#                     input_549621502 = cell.previousElementSibling;
#                 }
#                 input_549621502.style.display = "none"; // hide
#
#                 toggle_input_549621502 = function() {
#                     if (input_549621502.style.display == "none") {
#                         input_549621502.style.display = ""; // show
#                         link_549621502.innerHTML = "Hide Input";
#                     } else {
#                         input_549621502.style.display = "none"; // hide
#                         link_549621502.innerHTML = "Show Input";
#                     }
#                 }
#
#             } else {
#                 // jQuery
#                 var link_549621502 = $("a[id='549621502']");
#                 var cell_549621502 = link_549621502.parents("div.cell:first");
#                 if (cell_549621502.length == 0) {
#                     cell_549621502 = link_549621502.parents(
#                         "div.nboutput:first");
#                 }
#                 var input_549621502 = cell_549621502.children("div.input");
#                 if (input_549621502.length == 0) {
#                     input_549621502 = cell_549621502.prev("div.nbinput");
#                 }
#                 input_549621502.hide();
#
#                 toggle_input_549621502 = function() {
#                     if (input_549621502.is(':hidden')) {
#                         input_549621502.slideDown();
#                         link_549621502[0].innerHTML = "Hide Input";
#                     } else {
#                         input_549621502.slideUp();
#                         link_549621502[0].innerHTML = "Show Input";
#                     }
#                 }
#             }
#         }());
#         </script>

# %% [markdown]
# We can drive these neurons with our input signal
# and observe their spiking activity over time.

# %%
with model:
    nengo.Connection(input, A)
    A_spikes = nengo.Probe(A.neurons)

# %%
with nengo.Simulator(model) as sim:
    sim.run(1)

plt.figure()
ax = plt.subplot(1, 1, 1)
rasterplot(sim.trange(), sim.data[A_spikes], ax)
ax.set_xlim(0, 1)
ax.set_ylabel('Neuron')
ax.set_xlabel('Time (s)');
hide_input()
# Out:
#         <a id="101726377" href="javascript:toggle_input_101726377()"
#           >Show Input</a>
#
#         <script type="text/javascript">
#         var toggle_input_101726377;
#         (function() {
#             if (typeof jQuery == 'undefined') {
#                 // no jQuery
#                 var link_101726377 = document.getElementById("101726377");
#                 var cell = link_101726377;
#                 while (cell.className.split(' ')[0] != "cell"
#                        && cell.className.split(' ')[0] != "nboutput") {
#                     cell = cell.parentNode;
#                 }
#                 var input_101726377;
#                 if (cell.className.split(' ')[0] == "cell") {
#                     for (var i = 0; i < cell.children.length; i++) {
#                         if (cell.children[i].className.split(' ')[0]
#                             == "input") {
#                             input_101726377 = cell.children[i];
#                         }
#                     }
#                 } else {
#                     input_101726377 = cell.previousElementSibling;
#                 }
#                 input_101726377.style.display = "none"; // hide
#
#                 toggle_input_101726377 = function() {
#                     if (input_101726377.style.display == "none") {
#                         input_101726377.style.display = ""; // show
#                         link_101726377.innerHTML = "Hide Input";
#                     } else {
#                         input_101726377.style.display = "none"; // hide
#                         link_101726377.innerHTML = "Show Input";
#                     }
#                 }
#
#             } else {
#                 // jQuery
#                 var link_101726377 = $("a[id='101726377']");
#                 var cell_101726377 = link_101726377.parents("div.cell:first");
#                 if (cell_101726377.length == 0) {
#                     cell_101726377 = link_101726377.parents(
#                         "div.nboutput:first");
#                 }
#                 var input_101726377 = cell_101726377.children("div.input");
#                 if (input_101726377.length == 0) {
#                     input_101726377 = cell_101726377.prev("div.nbinput");
#                 }
#                 input_101726377.hide();
#
#                 toggle_input_101726377 = function() {
#                     if (input_101726377.is(':hidden')) {
#                         input_101726377.slideDown();
#                         link_101726377[0].innerHTML = "Hide Input";
#                     } else {
#                         input_101726377.slideUp();
#                         link_101726377[0].innerHTML = "Show Input";
#                     }
#                 }
#             }
#         }());
#         </script>

# %% [markdown]
# ### Decoding
#
# We can estimate the input signal
# originally encoded by decoding the pattern of spikes.
# To do this, we first filter the spike train
# with a temporal filter that accounts for
# postsynaptic current (PSC) activity.

# %%
model = nengo.Network(label="NEF summary")
with model:
    input = nengo.Node(lambda t: t * 2 - 1)
    input_probe = nengo.Probe(input)
    intercepts, encoders = aligned(8)  # Makes evenly spaced intercepts
    A = nengo.Ensemble(8, dimensions=1,
                       intercepts=intercepts,
                       max_rates=Uniform(80, 100),
                       encoders=encoders)
    nengo.Connection(input, A)
    A_spikes = nengo.Probe(A.neurons, synapse=0.01)

# %%
with nengo.Simulator(model) as sim:
    sim.run(1)

scale = 180
plt.figure()
for i in range(A.n_neurons):
    plt.plot(sim.trange(), sim.data[A_spikes][:, i] - i * scale)
plt.xlim(0, 1)
plt.ylim(scale * (-A.n_neurons + 1), scale)
plt.ylabel("Neuron")
plt.yticks(
    np.arange(scale / 1.8, (-A.n_neurons + 1) * scale, -scale),
    np.arange(A.n_neurons))
hide_input()
# Out:
#         <a id="1375396540" href="javascript:toggle_input_1375396540()"
#           >Show Input</a>
#
#         <script type="text/javascript">
#         var toggle_input_1375396540;
#         (function() {
#             if (typeof jQuery == 'undefined') {
#                 // no jQuery
#                 var link_1375396540 = document.getElementById("1375396540");
#                 var cell = link_1375396540;
#                 while (cell.className.split(' ')[0] != "cell"
#                        && cell.className.split(' ')[0] != "nboutput") {
#                     cell = cell.parentNode;
#                 }
#                 var input_1375396540;
#                 if (cell.className.split(' ')[0] == "cell") {
#                     for (var i = 0; i < cell.children.length; i++) {
#                         if (cell.children[i].className.split(' ')[0]
#                             == "input") {
#                             input_1375396540 = cell.children[i];
#                         }
#                     }
#                 } else {
#                     input_1375396540 = cell.previousElementSibling;
#                 }
#                 input_1375396540.style.display = "none"; // hide
#
#                 toggle_input_1375396540 = function() {
#                     if (input_1375396540.style.display == "none") {
#                         input_1375396540.style.display = ""; // show
#                         link_1375396540.innerHTML = "Hide Input";
#                     } else {
#                         input_1375396540.style.display = "none"; // hide
#                         link_1375396540.innerHTML = "Show Input";
#                     }
#                 }
#
#             } else {
#                 // jQuery
#                 var link_1375396540 = $("a[id='1375396540']");
#                 var cell_1375396540 = link_1375396540.parents("div.cell:first");
#                 if (cell_1375396540.length == 0) {
#                     cell_1375396540 = link_1375396540.parents(
#                         "div.nboutput:first");
#                 }
#                 var input_1375396540 = cell_1375396540.children("div.input");
#                 if (input_1375396540.length == 0) {
#                     input_1375396540 = cell_1375396540.prev("div.nbinput");
#                 }
#                 input_1375396540.hide();
#
#                 toggle_input_1375396540 = function() {
#                     if (input_1375396540.is(':hidden')) {
#                         input_1375396540.slideDown();
#                         link_1375396540[0].innerHTML = "Hide Input";
#                     } else {
#                         input_1375396540.slideUp();
#                         link_1375396540[0].innerHTML = "Show Input";
#                     }
#                 }
#             }
#         }());
#         </script>

# %% [markdown]
# Then we mulitply those filtered spike trains
# with decoding weights and sum them together
# to give an estimate of the input based on the spikes.
#
# The decoding weights are determined
# by minimizing the squared difference
# between the decoded estimate and the actual input signal.

# %%
with model:
    A_probe = nengo.Probe(A, synapse=0.01)  # 10ms PSC filter

# %%
with nengo.Simulator(model) as sim:
    sim.run(1)

plt.figure()
plt.plot(sim.trange(), sim.data[input_probe], label="Input signal")
plt.plot(sim.trange(), sim.data[A_probe], label="Decoded estimate")
plt.legend(loc="best")
plt.xlim(0, 1)
hide_input()
# Out:
#         <a id="2000666295" href="javascript:toggle_input_2000666295()"
#           >Show Input</a>
#
#         <script type="text/javascript">
#         var toggle_input_2000666295;
#         (function() {
#             if (typeof jQuery == 'undefined') {
#                 // no jQuery
#                 var link_2000666295 = document.getElementById("2000666295");
#                 var cell = link_2000666295;
#                 while (cell.className.split(' ')[0] != "cell"
#                        && cell.className.split(' ')[0] != "nboutput") {
#                     cell = cell.parentNode;
#                 }
#                 var input_2000666295;
#                 if (cell.className.split(' ')[0] == "cell") {
#                     for (var i = 0; i < cell.children.length; i++) {
#                         if (cell.children[i].className.split(' ')[0]
#                             == "input") {
#                             input_2000666295 = cell.children[i];
#                         }
#                     }
#                 } else {
#                     input_2000666295 = cell.previousElementSibling;
#                 }
#                 input_2000666295.style.display = "none"; // hide
#
#                 toggle_input_2000666295 = function() {
#                     if (input_2000666295.style.display == "none") {
#                         input_2000666295.style.display = ""; // show
#                         link_2000666295.innerHTML = "Hide Input";
#                     } else {
#                         input_2000666295.style.display = "none"; // hide
#                         link_2000666295.innerHTML = "Show Input";
#                     }
#                 }
#
#             } else {
#                 // jQuery
#                 var link_2000666295 = $("a[id='2000666295']");
#                 var cell_2000666295 = link_2000666295.parents("div.cell:first");
#                 if (cell_2000666295.length == 0) {
#                     cell_2000666295 = link_2000666295.parents(
#                         "div.nboutput:first");
#                 }
#                 var input_2000666295 = cell_2000666295.children("div.input");
#                 if (input_2000666295.length == 0) {
#                     input_2000666295 = cell_2000666295.prev("div.nbinput");
#                 }
#                 input_2000666295.hide();
#
#                 toggle_input_2000666295 = function() {
#                     if (input_2000666295.is(':hidden')) {
#                         input_2000666295.slideDown();
#                         link_2000666295[0].innerHTML = "Hide Input";
#                     } else {
#                         input_2000666295.slideUp();
#                         link_2000666295[0].innerHTML = "Show Input";
#                     }
#                 }
#             }
#         }());
#         </script>

# %% [markdown]
# The accuracy of the decoded estimate increases
# as the number of neurons increases.

# %%
model = nengo.Network(label="NEF summary")
with model:
    input = nengo.Node(lambda t: t * 2 - 1)
    input_probe = nengo.Probe(input)
    A = nengo.Ensemble(30, dimensions=1, max_rates=Uniform(80, 100))
    nengo.Connection(input, A)
    A_spikes = nengo.Probe(A.neurons)
    A_probe = nengo.Probe(A, synapse=0.01)

# %%
with nengo.Simulator(model) as sim:
    sim.run(1)

plt.figure(figsize=(15, 3.5))

plt.subplot(1, 3, 1)
eval_points, activities = tuning_curves(A, sim)
plt.plot(eval_points, activities, lw=2)
plt.xlabel("Input signal")
plt.ylabel("Firing rate (Hz)")

ax = plt.subplot(1, 3, 2)
rasterplot(sim.trange(), sim.data[A_spikes], ax)
plt.xlim(0, 1)
plt.xlabel("Time (s)")
plt.ylabel("Neuron")

plt.subplot(1, 3, 3)
plt.plot(sim.trange(), sim.data[input_probe], label="Input signal")
plt.plot(sim.trange(), sim.data[A_probe], label="Decoded esimate")
plt.legend(loc="best")
plt.xlabel("Time (s)")
plt.xlim(0, 1)
hide_input()
# Out:
#         <a id="518365455" href="javascript:toggle_input_518365455()"
#           >Show Input</a>
#
#         <script type="text/javascript">
#         var toggle_input_518365455;
#         (function() {
#             if (typeof jQuery == 'undefined') {
#                 // no jQuery
#                 var link_518365455 = document.getElementById("518365455");
#                 var cell = link_518365455;
#                 while (cell.className.split(' ')[0] != "cell"
#                        && cell.className.split(' ')[0] != "nboutput") {
#                     cell = cell.parentNode;
#                 }
#                 var input_518365455;
#                 if (cell.className.split(' ')[0] == "cell") {
#                     for (var i = 0; i < cell.children.length; i++) {
#                         if (cell.children[i].className.split(' ')[0]
#                             == "input") {
#                             input_518365455 = cell.children[i];
#                         }
#                     }
#                 } else {
#                     input_518365455 = cell.previousElementSibling;
#                 }
#                 input_518365455.style.display = "none"; // hide
#
#                 toggle_input_518365455 = function() {
#                     if (input_518365455.style.display == "none") {
#                         input_518365455.style.display = ""; // show
#                         link_518365455.innerHTML = "Hide Input";
#                     } else {
#                         input_518365455.style.display = "none"; // hide
#                         link_518365455.innerHTML = "Show Input";
#                     }
#                 }
#
#             } else {
#                 // jQuery
#                 var link_518365455 = $("a[id='518365455']");
#                 var cell_518365455 = link_518365455.parents("div.cell:first");
#                 if (cell_518365455.length == 0) {
#                     cell_518365455 = link_518365455.parents(
#                         "div.nboutput:first");
#                 }
#                 var input_518365455 = cell_518365455.children("div.input");
#                 if (input_518365455.length == 0) {
#                     input_518365455 = cell_518365455.prev("div.nbinput");
#                 }
#                 input_518365455.hide();
#
#                 toggle_input_518365455 = function() {
#                     if (input_518365455.is(':hidden')) {
#                         input_518365455.slideDown();
#                         link_518365455[0].innerHTML = "Hide Input";
#                     } else {
#                         input_518365455.slideUp();
#                         link_518365455[0].innerHTML = "Show Input";
#                     }
#                 }
#             }
#         }());
#         </script>

# %% [markdown]
# Any smooth signal can be encoded and decoded.

# %%
model = nengo.Network(label="NEF summary")
with model:
    input = nengo.Node(WhiteSignal(1, high=5), size_out=1)
    input_probe = nengo.Probe(input)
    A = nengo.Ensemble(30, dimensions=1, max_rates=Uniform(80, 100))
    nengo.Connection(input, A)
    A_spikes = nengo.Probe(A.neurons)
    A_probe = nengo.Probe(A, synapse=0.01)

# %%
with nengo.Simulator(model) as sim:
    sim.run(1)

plt.figure(figsize=(10, 3.5))
plt.subplot(1, 2, 1)
plt.plot(sim.trange(), sim.data[input_probe], label="Input signal")
plt.plot(sim.trange(), sim.data[A_probe], label="Decoded esimate")
plt.legend(loc="best")
plt.xlabel("Time (s)")
plt.xlim(0, 1)

ax = plt.subplot(1, 2, 2)
rasterplot(sim.trange(), sim.data[A_spikes], ax)
plt.xlim(0, 1)
plt.xlabel("Time (s)")
plt.ylabel("Neuron")
hide_input()
# Out:
#         <a id="1826260580" href="javascript:toggle_input_1826260580()"
#           >Show Input</a>
#
#         <script type="text/javascript">
#         var toggle_input_1826260580;
#         (function() {
#             if (typeof jQuery == 'undefined') {
#                 // no jQuery
#                 var link_1826260580 = document.getElementById("1826260580");
#                 var cell = link_1826260580;
#                 while (cell.className.split(' ')[0] != "cell"
#                        && cell.className.split(' ')[0] != "nboutput") {
#                     cell = cell.parentNode;
#                 }
#                 var input_1826260580;
#                 if (cell.className.split(' ')[0] == "cell") {
#                     for (var i = 0; i < cell.children.length; i++) {
#                         if (cell.children[i].className.split(' ')[0]
#                             == "input") {
#                             input_1826260580 = cell.children[i];
#                         }
#                     }
#                 } else {
#                     input_1826260580 = cell.previousElementSibling;
#                 }
#                 input_1826260580.style.display = "none"; // hide
#
#                 toggle_input_1826260580 = function() {
#                     if (input_1826260580.style.display == "none") {
#                         input_1826260580.style.display = ""; // show
#                         link_1826260580.innerHTML = "Hide Input";
#                     } else {
#                         input_1826260580.style.display = "none"; // hide
#                         link_1826260580.innerHTML = "Show Input";
#                     }
#                 }
#
#             } else {
#                 // jQuery
#                 var link_1826260580 = $("a[id='1826260580']");
#                 var cell_1826260580 = link_1826260580.parents("div.cell:first");
#                 if (cell_1826260580.length == 0) {
#                     cell_1826260580 = link_1826260580.parents(
#                         "div.nboutput:first");
#                 }
#                 var input_1826260580 = cell_1826260580.children("div.input");
#                 if (input_1826260580.length == 0) {
#                     input_1826260580 = cell_1826260580.prev("div.nbinput");
#                 }
#                 input_1826260580.hide();
#
#                 toggle_input_1826260580 = function() {
#                     if (input_1826260580.is(':hidden')) {
#                         input_1826260580.slideDown();
#                         link_1826260580[0].innerHTML = "Hide Input";
#                     } else {
#                         input_1826260580.slideUp();
#                         link_1826260580[0].innerHTML = "Show Input";
#                     }
#                 }
#             }
#         }());
#         </script>

# %% [markdown]
# ## Principle 2: Transformation
#
# Encoding and decoding allow us to encode signals over time,
# and decode transformations of those signals.
#
# In fact, we can decode arbitrary transformations of the input signal,
# not just the signal itself (as in the previous example).
#
# Let's decode the square of our white noise input.

# %%
model = nengo.Network(label="NEF summary")
with model:
    input = nengo.Node(WhiteSignal(1, high=5), size_out=1)
    input_probe = nengo.Probe(input, )
    A = nengo.Ensemble(30, dimensions=1, max_rates=Uniform(80, 100))
    Asquare = nengo.Node(size_in=1)
    nengo.Connection(input, A)
    nengo.Connection(A, Asquare, function=np.square)
    A_spikes = nengo.Probe(A.neurons)
    Asquare_probe = nengo.Probe(Asquare, synapse=0.01)

# %%
with nengo.Simulator(model) as sim:
    sim.run(1)

plt.figure(figsize=(10, 3.5))
plt.subplot(1, 2, 1)
plt.plot(
    sim.trange(),
    sim.data[input_probe],
    label="Input signal")
plt.plot(
    sim.trange(),
    sim.data[Asquare_probe],
    label="Decoded esimate")
plt.plot(
    sim.trange(),
    np.square(sim.data[input_probe]),
    label="Input signal squared")
plt.legend(loc="best", fontsize='medium')
plt.xlabel("Time (s)")
plt.xlim(0, 1)

ax = plt.subplot(1, 2, 2)
rasterplot(sim.trange(), sim.data[A_spikes])
plt.xlim(0, 1)
plt.xlabel("Time (s)")
plt.ylabel("Neuron")
hide_input()
# Out:
#         <a id="1328742127" href="javascript:toggle_input_1328742127()"
#           >Show Input</a>
#
#         <script type="text/javascript">
#         var toggle_input_1328742127;
#         (function() {
#             if (typeof jQuery == 'undefined') {
#                 // no jQuery
#                 var link_1328742127 = document.getElementById("1328742127");
#                 var cell = link_1328742127;
#                 while (cell.className.split(' ')[0] != "cell"
#                        && cell.className.split(' ')[0] != "nboutput") {
#                     cell = cell.parentNode;
#                 }
#                 var input_1328742127;
#                 if (cell.className.split(' ')[0] == "cell") {
#                     for (var i = 0; i < cell.children.length; i++) {
#                         if (cell.children[i].className.split(' ')[0]
#                             == "input") {
#                             input_1328742127 = cell.children[i];
#                         }
#                     }
#                 } else {
#                     input_1328742127 = cell.previousElementSibling;
#                 }
#                 input_1328742127.style.display = "none"; // hide
#
#                 toggle_input_1328742127 = function() {
#                     if (input_1328742127.style.display == "none") {
#                         input_1328742127.style.display = ""; // show
#                         link_1328742127.innerHTML = "Hide Input";
#                     } else {
#                         input_1328742127.style.display = "none"; // hide
#                         link_1328742127.innerHTML = "Show Input";
#                     }
#                 }
#
#             } else {
#                 // jQuery
#                 var link_1328742127 = $("a[id='1328742127']");
#                 var cell_1328742127 = link_1328742127.parents("div.cell:first");
#                 if (cell_1328742127.length == 0) {
#                     cell_1328742127 = link_1328742127.parents(
#                         "div.nboutput:first");
#                 }
#                 var input_1328742127 = cell_1328742127.children("div.input");
#                 if (input_1328742127.length == 0) {
#                     input_1328742127 = cell_1328742127.prev("div.nbinput");
#                 }
#                 input_1328742127.hide();
#
#                 toggle_input_1328742127 = function() {
#                     if (input_1328742127.is(':hidden')) {
#                         input_1328742127.slideDown();
#                         link_1328742127[0].innerHTML = "Hide Input";
#                     } else {
#                         input_1328742127.slideUp();
#                         link_1328742127[0].innerHTML = "Show Input";
#                     }
#                 }
#             }
#         }());
#         </script>

# %% [markdown]
# Notice that the spike trains are exactly the same.
# The only difference is how we're interpreting those spikes.
# We told Nengo to compute a new set of decoders
# that estimate the function $x^2$.
#
# In general, the transformation principle
# determines how we can decode spike trains
# to compute linear and nonlinear transformations of signals
# encoded in a population of neurons.
# We can then project those transformed signals
# into another population, and repeat the process.
# Essentially, this provides a means of
# computing the neural connection weights
# to compute an arbitrary function between populations.
#
# Suppose we are representing a sine wave.

# %%
model = nengo.Network(label="NEF summary")
with model:
    input = nengo.Node(lambda t: np.sin(np.pi * t))
    A = nengo.Ensemble(30, dimensions=1, max_rates=Uniform(80, 100))
    nengo.Connection(input, A)
    A_spikes = nengo.Probe(A.neurons)
    A_probe = nengo.Probe(A, synapse=0.01)

# %%
with nengo.Simulator(model) as sim:
    sim.run(2)

plt.figure(figsize=(10, 3.5))
plt.subplot(1, 2, 1)
plt.plot(sim.trange(), sim.data[A_probe])
plt.title("A")
plt.xlabel("Time (s)")
plt.xlim(0, 2)

ax = plt.subplot(1, 2, 2)
rasterplot(sim.trange(), sim.data[A_spikes], ax)
plt.xlim(0, 2)
plt.title("A")
plt.xlabel("Time (s)")
plt.ylabel("Neuron")
hide_input()
# Out:
#         <a id="551337510" href="javascript:toggle_input_551337510()"
#           >Show Input</a>
#
#         <script type="text/javascript">
#         var toggle_input_551337510;
#         (function() {
#             if (typeof jQuery == 'undefined') {
#                 // no jQuery
#                 var link_551337510 = document.getElementById("551337510");
#                 var cell = link_551337510;
#                 while (cell.className.split(' ')[0] != "cell"
#                        && cell.className.split(' ')[0] != "nboutput") {
#                     cell = cell.parentNode;
#                 }
#                 var input_551337510;
#                 if (cell.className.split(' ')[0] == "cell") {
#                     for (var i = 0; i < cell.children.length; i++) {
#                         if (cell.children[i].className.split(' ')[0]
#                             == "input") {
#                             input_551337510 = cell.children[i];
#                         }
#                     }
#                 } else {
#                     input_551337510 = cell.previousElementSibling;
#                 }
#                 input_551337510.style.display = "none"; // hide
#
#                 toggle_input_551337510 = function() {
#                     if (input_551337510.style.display == "none") {
#                         input_551337510.style.display = ""; // show
#                         link_551337510.innerHTML = "Hide Input";
#                     } else {
#                         input_551337510.style.display = "none"; // hide
#                         link_551337510.innerHTML = "Show Input";
#                     }
#                 }
#
#             } else {
#                 // jQuery
#                 var link_551337510 = $("a[id='551337510']");
#                 var cell_551337510 = link_551337510.parents("div.cell:first");
#                 if (cell_551337510.length == 0) {
#                     cell_551337510 = link_551337510.parents(
#                         "div.nboutput:first");
#                 }
#                 var input_551337510 = cell_551337510.children("div.input");
#                 if (input_551337510.length == 0) {
#                     input_551337510 = cell_551337510.prev("div.nbinput");
#                 }
#                 input_551337510.hide();
#
#                 toggle_input_551337510 = function() {
#                     if (input_551337510.is(':hidden')) {
#                         input_551337510.slideDown();
#                         link_551337510[0].innerHTML = "Hide Input";
#                     } else {
#                         input_551337510.slideUp();
#                         link_551337510[0].innerHTML = "Show Input";
#                     }
#                 }
#             }
#         }());
#         </script>

# %% [markdown]
# Linear transformations of that signal
# involve solving for the usual decoders,
# and scaling those decoding weights.
# Let us flip this sine wave upside down
# as it is transmitted between two populations
# (i.e. population A and population -A).

# %%
with model:
    minusA = nengo.Ensemble(30, dimensions=1, max_rates=Uniform(80, 100))
    nengo.Connection(A, minusA, function=lambda x: -x)
    minusA_spikes = nengo.Probe(minusA.neurons)
    minusA_probe = nengo.Probe(minusA, synapse=0.01)

# %%
with nengo.Simulator(model) as sim:
    sim.run(2)

plt.figure(figsize=(10, 5))
plt.subplot(2, 2, 1)
plt.plot(sim.trange(), sim.data[A_probe])
plt.title("A")
plt.xticks(())
plt.xlim(0, 2)

plt.subplot(2, 2, 3)
plt.plot(sim.trange(), sim.data[minusA_probe])
plt.title("-A")
plt.xlabel("Time (s)")
plt.xlim(0, 2)

ax = plt.subplot(2, 2, 2)
rasterplot(sim.trange(), sim.data[A_spikes], ax)
plt.xlim(0, 2)
plt.title("A")
plt.xticks(())
plt.ylabel("Neuron")

ax = plt.subplot(2, 2, 4)
rasterplot(sim.trange(), sim.data[minusA_spikes], ax)
plt.xlim(0, 2)
plt.title("-A")
plt.xlabel("Time (s)")
plt.ylabel("Neuron")
hide_input()
# Out:
#         <a id="1233047707" href="javascript:toggle_input_1233047707()"
#           >Show Input</a>
#
#         <script type="text/javascript">
#         var toggle_input_1233047707;
#         (function() {
#             if (typeof jQuery == 'undefined') {
#                 // no jQuery
#                 var link_1233047707 = document.getElementById("1233047707");
#                 var cell = link_1233047707;
#                 while (cell.className.split(' ')[0] != "cell"
#                        && cell.className.split(' ')[0] != "nboutput") {
#                     cell = cell.parentNode;
#                 }
#                 var input_1233047707;
#                 if (cell.className.split(' ')[0] == "cell") {
#                     for (var i = 0; i < cell.children.length; i++) {
#                         if (cell.children[i].className.split(' ')[0]
#                             == "input") {
#                             input_1233047707 = cell.children[i];
#                         }
#                     }
#                 } else {
#                     input_1233047707 = cell.previousElementSibling;
#                 }
#                 input_1233047707.style.display = "none"; // hide
#
#                 toggle_input_1233047707 = function() {
#                     if (input_1233047707.style.display == "none") {
#                         input_1233047707.style.display = ""; // show
#                         link_1233047707.innerHTML = "Hide Input";
#                     } else {
#                         input_1233047707.style.display = "none"; // hide
#                         link_1233047707.innerHTML = "Show Input";
#                     }
#                 }
#
#             } else {
#                 // jQuery
#                 var link_1233047707 = $("a[id='1233047707']");
#                 var cell_1233047707 = link_1233047707.parents("div.cell:first");
#                 if (cell_1233047707.length == 0) {
#                     cell_1233047707 = link_1233047707.parents(
#                         "div.nboutput:first");
#                 }
#                 var input_1233047707 = cell_1233047707.children("div.input");
#                 if (input_1233047707.length == 0) {
#                     input_1233047707 = cell_1233047707.prev("div.nbinput");
#                 }
#                 input_1233047707.hide();
#
#                 toggle_input_1233047707 = function() {
#                     if (input_1233047707.is(':hidden')) {
#                         input_1233047707.slideDown();
#                         link_1233047707[0].innerHTML = "Hide Input";
#                     } else {
#                         input_1233047707.slideUp();
#                         link_1233047707[0].innerHTML = "Show Input";
#                     }
#                 }
#             }
#         }());
#         </script>

# %% [markdown]
# Nonlinear transformations involve
# solving for a new set of decoding weights.
# Let us add a third population connected
# to the second one and use it to compute $(-A)^2$.

# %%
with model:
    A_squared = nengo.Ensemble(30, dimensions=1, max_rates=Uniform(80, 100))
    nengo.Connection(minusA, A_squared, function=lambda x: x ** 2)
    A_squared_spikes = nengo.Probe(A_squared.neurons)
    A_squared_probe = nengo.Probe(A_squared, synapse=0.02)

# %%
with nengo.Simulator(model) as sim:
    sim.run(2)

plt.figure(figsize=(10, 6.5))
plt.subplot(3, 2, 1)
plt.plot(sim.trange(), sim.data[A_probe])
plt.axhline(0, color='k')
plt.title("A")
plt.xticks(())
plt.xlim(0, 2)

plt.subplot(3, 2, 3)
plt.plot(sim.trange(), sim.data[minusA_probe])
plt.axhline(0, color='k')
plt.title("-A")
plt.xticks(())
plt.xlim(0, 2)

plt.subplot(3, 2, 5)
plt.plot(sim.trange(), sim.data[A_squared_probe])
plt.axhline(0, color='k')
plt.title("(-A)^2")
plt.xlabel("Time (s)")
plt.xlim(0, 2)

ax = plt.subplot(3, 2, 2)
rasterplot(sim.trange(), sim.data[A_spikes], ax)
plt.xlim(0, 2)
plt.title("A")
plt.xticks(())
plt.ylabel("Neuron")

ax = plt.subplot(3, 2, 4)
rasterplot(sim.trange(), sim.data[minusA_spikes], ax)
plt.xlim(0, 2)
plt.title("-A")
plt.xticks(())
plt.ylabel("Neuron")

ax = plt.subplot(3, 2, 6)
rasterplot(sim.trange(), sim.data[A_squared_spikes], ax)
plt.xlim(0, 2)
plt.title("(-A)^2")
plt.xlabel("Time (s)")
plt.ylabel("Neuron")
hide_input()
# Out:
#         <a id="665098229" href="javascript:toggle_input_665098229()"
#           >Show Input</a>
#
#         <script type="text/javascript">
#         var toggle_input_665098229;
#         (function() {
#             if (typeof jQuery == 'undefined') {
#                 // no jQuery
#                 var link_665098229 = document.getElementById("665098229");
#                 var cell = link_665098229;
#                 while (cell.className.split(' ')[0] != "cell"
#                        && cell.className.split(' ')[0] != "nboutput") {
#                     cell = cell.parentNode;
#                 }
#                 var input_665098229;
#                 if (cell.className.split(' ')[0] == "cell") {
#                     for (var i = 0; i < cell.children.length; i++) {
#                         if (cell.children[i].className.split(' ')[0]
#                             == "input") {
#                             input_665098229 = cell.children[i];
#                         }
#                     }
#                 } else {
#                     input_665098229 = cell.previousElementSibling;
#                 }
#                 input_665098229.style.display = "none"; // hide
#
#                 toggle_input_665098229 = function() {
#                     if (input_665098229.style.display == "none") {
#                         input_665098229.style.display = ""; // show
#                         link_665098229.innerHTML = "Hide Input";
#                     } else {
#                         input_665098229.style.display = "none"; // hide
#                         link_665098229.innerHTML = "Show Input";
#                     }
#                 }
#
#             } else {
#                 // jQuery
#                 var link_665098229 = $("a[id='665098229']");
#                 var cell_665098229 = link_665098229.parents("div.cell:first");
#                 if (cell_665098229.length == 0) {
#                     cell_665098229 = link_665098229.parents(
#                         "div.nboutput:first");
#                 }
#                 var input_665098229 = cell_665098229.children("div.input");
#                 if (input_665098229.length == 0) {
#                     input_665098229 = cell_665098229.prev("div.nbinput");
#                 }
#                 input_665098229.hide();
#
#                 toggle_input_665098229 = function() {
#                     if (input_665098229.is(':hidden')) {
#                         input_665098229.slideDown();
#                         link_665098229[0].innerHTML = "Hide Input";
#                     } else {
#                         input_665098229.slideUp();
#                         link_665098229[0].innerHTML = "Show Input";
#                     }
#                 }
#             }
#         }());
#         </script>

# %% [markdown]
# ## Principle 3: Dynamics
#
# So far, we have been considering the values
# represented by ensembles as generic "signals."
# However, if we think of them instead
# as state variables in a dynamical system,
# then we can apply the methods of control theory
# or dynamic systems theory to brain models.
# Nengo automatically translates from standard dynamical systems descriptions
# to descriptions consistent with neural dynamics.
#
# In order to get interesting dynamics,
# we can connect populations recurrently (i.e., to themselves).
#
# Below is a simple harmonic oscillator
# implemented using this third principle.
# It needs is a bit of input to get it started.

# %%
model = nengo.Network(label="NEF summary")
with model:
    input = nengo.Node(lambda t: [1, 0] if t < 0.1 else [0, 0])
    oscillator = nengo.Ensemble(200, dimensions=2)
    nengo.Connection(input, oscillator)
    nengo.Connection(
        oscillator, oscillator, transform=[[1, 1], [-1, 1]], synapse=0.1)
    oscillator_probe = nengo.Probe(oscillator, synapse=0.02)

# %%
with nengo.Simulator(model) as sim:
    sim.run(3)

plt.figure(figsize=(10, 3.5))
plt.subplot(1, 2, 1)
plt.plot(sim.trange(), sim.data[oscillator_probe])
plt.ylim(-1.2, 1.2)
plt.xlabel('Time (s)')

plt.subplot(1, 2, 2)
plt.plot(sim.data[oscillator_probe][:, 0], sim.data[oscillator_probe][:, 1])
plt.grid()
plt.axis([-1.2, 1.2, -1.2, 1.2])
plt.xlabel('$x_1$')
plt.ylabel('$x_2$')
hide_input()
# Out:
#         <a id="934666570" href="javascript:toggle_input_934666570()"
#           >Show Input</a>
#
#         <script type="text/javascript">
#         var toggle_input_934666570;
#         (function() {
#             if (typeof jQuery == 'undefined') {
#                 // no jQuery
#                 var link_934666570 = document.getElementById("934666570");
#                 var cell = link_934666570;
#                 while (cell.className.split(' ')[0] != "cell"
#                        && cell.className.split(' ')[0] != "nboutput") {
#                     cell = cell.parentNode;
#                 }
#                 var input_934666570;
#                 if (cell.className.split(' ')[0] == "cell") {
#                     for (var i = 0; i < cell.children.length; i++) {
#                         if (cell.children[i].className.split(' ')[0]
#                             == "input") {
#                             input_934666570 = cell.children[i];
#                         }
#                     }
#                 } else {
#                     input_934666570 = cell.previousElementSibling;
#                 }
#                 input_934666570.style.display = "none"; // hide
#
#                 toggle_input_934666570 = function() {
#                     if (input_934666570.style.display == "none") {
#                         input_934666570.style.display = ""; // show
#                         link_934666570.innerHTML = "Hide Input";
#                     } else {
#                         input_934666570.style.display = "none"; // hide
#                         link_934666570.innerHTML = "Show Input";
#                     }
#                 }
#
#             } else {
#                 // jQuery
#                 var link_934666570 = $("a[id='934666570']");
#                 var cell_934666570 = link_934666570.parents("div.cell:first");
#                 if (cell_934666570.length == 0) {
#                     cell_934666570 = link_934666570.parents(
#                         "div.nboutput:first");
#                 }
#                 var input_934666570 = cell_934666570.children("div.input");
#                 if (input_934666570.length == 0) {
#                     input_934666570 = cell_934666570.prev("div.nbinput");
#                 }
#                 input_934666570.hide();
#
#                 toggle_input_934666570 = function() {
#                     if (input_934666570.is(':hidden')) {
#                         input_934666570.slideDown();
#                         link_934666570[0].innerHTML = "Hide Input";
#                     } else {
#                         input_934666570.slideUp();
#                         link_934666570[0].innerHTML = "Show Input";
#                     }
#                 }
#             }
#         }());
#         </script>
