# %% [markdown]
# # NEF summary
#
# The Neural Engineering Framework (NEF)
# is one set of theoretical methods that are used in
# Nengo for constructing neural models.
# The NEF is based on [Eliasmith & Anderson's (2003) book](
# https://mitpress.mit.edu/books/neural-engineering) from MIT Press.
# This notebook introduces the three main principles
# discussed in that book and implemented in Nengo.

# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt

import nengo
from nengo.dists import Uniform
from nengo.processes import WhiteSignal
from nengo.utils.ensemble import tuning_curves
from nengo.utils.ipython import hide_input
from nengo.utils.matplotlib import rasterplot


def aligned(n_neurons, radius=0.9):
    intercepts = np.linspace(-radius, radius, n_neurons)
    encoders = np.tile([[1], [-1]], (n_neurons // 2, 1))
    intercepts *= encoders[:, 0]
    return intercepts, encoders


hide_input()
# Out:
#         <a id="1151108942" href="javascript:toggle_input_1151108942()"
#           >Show Input</a>
#
#         <script type="text/javascript">
#         var toggle_input_1151108942;
#         (function() {
#             if (typeof jQuery == 'undefined') {
#                 // no jQuery
#                 var link_1151108942 = document.getElementById("1151108942");
#                 var cell = link_1151108942;
#                 while (cell.className.split(' ')[0] != "cell"
#                        && cell.className.split(' ')[0] != "nboutput") {
#                     cell = cell.parentNode;
#                 }
#                 var input_1151108942;
#                 if (cell.className.split(' ')[0] == "cell") {
#                     for (var i = 0; i < cell.children.length; i++) {
#                         if (cell.children[i].className.split(' ')[0]
#                             == "input") {
#                             input_1151108942 = cell.children[i];
#                         }
#                     }
#                 } else {
#                     input_1151108942 = cell.previousElementSibling;
#                 }
#                 input_1151108942.style.display = "none"; // hide
#
#                 toggle_input_1151108942 = function() {
#                     if (input_1151108942.style.display == "none") {
#                         input_1151108942.style.display = ""; // show
#                         link_1151108942.innerHTML = "Hide Input";
#                     } else {
#                         input_1151108942.style.display = "none"; // hide
#                         link_1151108942.innerHTML = "Show Input";
#                     }
#                 }
#
#             } else {
#                 // jQuery
#                 var link_1151108942 = $("a[id='1151108942']");
#                 var cell_1151108942 = link_1151108942.parents("div.cell:first");
#                 if (cell_1151108942.length == 0) {
#                     cell_1151108942 = link_1151108942.parents(
#                         "div.nboutput:first");
#                 }
#                 var input_1151108942 = cell_1151108942.children("div.input");
#                 if (input_1151108942.length == 0) {
#                     input_1151108942 = cell_1151108942.prev("div.nbinput");
#                 }
#                 input_1151108942.hide();
#
#                 toggle_input_1151108942 = function() {
#                     if (input_1151108942.is(':hidden')) {
#                         input_1151108942.slideDown();
#                         link_1151108942[0].innerHTML = "Hide Input";
#                     } else {
#                         input_1151108942.slideUp();
#                         link_1151108942[0].innerHTML = "Show Input";
#                     }
#                 }
#             }
#         }());
#         </script>

# %% [markdown]
# ## Principle 1: Representation
#
# ### Encoding
#
# Neural populations represent time-varying signals
# through their spiking responses.
# A signal is a vector of real numbers of arbitrary length.
# This example is a 1D signal going from -1 to 1 in 1 second.

# %%
model = nengo.Network(label="NEF summary")
with model:
    input = nengo.Node(lambda t: t * 2 - 1)
    input_probe = nengo.Probe(input)

# %%
with nengo.Simulator(model) as sim:
    sim.run(1.0)

plt.figure()
plt.plot(sim.trange(), sim.data[input_probe], lw=2)
plt.title("Input signal")
plt.xlabel("Time (s)")
plt.xlim(0, 1);
hide_input()
# Out:
#         <a id="2069304030" href="javascript:toggle_input_2069304030()"
#           >Show Input</a>
#
#         <script type="text/javascript">
#         var toggle_input_2069304030;
#         (function() {
#             if (typeof jQuery == 'undefined') {
#                 // no jQuery
#                 var link_2069304030 = document.getElementById("2069304030");
#                 var cell = link_2069304030;
#                 while (cell.className.split(' ')[0] != "cell"
#                        && cell.className.split(' ')[0] != "nboutput") {
#                     cell = cell.parentNode;
#                 }
#                 var input_2069304030;
#                 if (cell.className.split(' ')[0] == "cell") {
#                     for (var i = 0; i < cell.children.length; i++) {
#                         if (cell.children[i].className.split(' ')[0]
#                             == "input") {
#                             input_2069304030 = cell.children[i];
#                         }
#                     }
#                 } else {
#                     input_2069304030 = cell.previousElementSibling;
#                 }
#                 input_2069304030.style.display = "none"; // hide
#
#                 toggle_input_2069304030 = function() {
#                     if (input_2069304030.style.display == "none") {
#                         input_2069304030.style.display = ""; // show
#                         link_2069304030.innerHTML = "Hide Input";
#                     } else {
#                         input_2069304030.style.display = "none"; // hide
#                         link_2069304030.innerHTML = "Show Input";
#                     }
#                 }
#
#             } else {
#                 // jQuery
#                 var link_2069304030 = $("a[id='2069304030']");
#                 var cell_2069304030 = link_2069304030.parents("div.cell:first");
#                 if (cell_2069304030.length == 0) {
#                     cell_2069304030 = link_2069304030.parents(
#                         "div.nboutput:first");
#                 }
#                 var input_2069304030 = cell_2069304030.children("div.input");
#                 if (input_2069304030.length == 0) {
#                     input_2069304030 = cell_2069304030.prev("div.nbinput");
#                 }
#                 input_2069304030.hide();
#
#                 toggle_input_2069304030 = function() {
#                     if (input_2069304030.is(':hidden')) {
#                         input_2069304030.slideDown();
#                         link_2069304030[0].innerHTML = "Hide Input";
#                     } else {
#                         input_2069304030.slideUp();
#                         link_2069304030[0].innerHTML = "Show Input";
#                     }
#                 }
#             }
#         }());
#         </script>

# %% [markdown]
# These signals drive neural populations
# based on each neuron's *tuning curve*
# (which is similar to the current-frequency curve,
# if you're familiar with that).
#
# The tuning curve describes how much
# a particular neuron will fire as a function of the input signal.

# %%
intercepts, encoders = aligned(8)  # Makes evenly spaced intercepts
with model:
    A = nengo.Ensemble(
        8,
        dimensions=1,
        intercepts=intercepts,
        max_rates=Uniform(80, 100),
        encoders=encoders)

# %%
with nengo.Simulator(model) as sim:
    eval_points, activities = tuning_curves(A, sim)

plt.figure()
plt.plot(eval_points, activities, lw=2)
plt.xlabel("Input signal")
plt.ylabel("Firing rate (Hz)");
hide_input()
# Out:
#         <a id="1491886632" href="javascript:toggle_input_1491886632()"
#           >Show Input</a>
#
#         <script type="text/javascript">
#         var toggle_input_1491886632;
#         (function() {
#             if (typeof jQuery == 'undefined') {
#                 // no jQuery
#                 var link_1491886632 = document.getElementById("1491886632");
#                 var cell = link_1491886632;
#                 while (cell.className.split(' ')[0] != "cell"
#                        && cell.className.split(' ')[0] != "nboutput") {
#                     cell = cell.parentNode;
#                 }
#                 var input_1491886632;
#                 if (cell.className.split(' ')[0] == "cell") {
#                     for (var i = 0; i < cell.children.length; i++) {
#                         if (cell.children[i].className.split(' ')[0]
#                             == "input") {
#                             input_1491886632 = cell.children[i];
#                         }
#                     }
#                 } else {
#                     input_1491886632 = cell.previousElementSibling;
#                 }
#                 input_1491886632.style.display = "none"; // hide
#
#                 toggle_input_1491886632 = function() {
#                     if (input_1491886632.style.display == "none") {
#                         input_1491886632.style.display = ""; // show
#                         link_1491886632.innerHTML = "Hide Input";
#                     } else {
#                         input_1491886632.style.display = "none"; // hide
#                         link_1491886632.innerHTML = "Show Input";
#                     }
#                 }
#
#             } else {
#                 // jQuery
#                 var link_1491886632 = $("a[id='1491886632']");
#                 var cell_1491886632 = link_1491886632.parents("div.cell:first");
#                 if (cell_1491886632.length == 0) {
#                     cell_1491886632 = link_1491886632.parents(
#                         "div.nboutput:first");
#                 }
#                 var input_1491886632 = cell_1491886632.children("div.input");
#                 if (input_1491886632.length == 0) {
#                     input_1491886632 = cell_1491886632.prev("div.nbinput");
#                 }
#                 input_1491886632.hide();
#
#                 toggle_input_1491886632 = function() {
#                     if (input_1491886632.is(':hidden')) {
#                         input_1491886632.slideDown();
#                         link_1491886632[0].innerHTML = "Hide Input";
#                     } else {
#                         input_1491886632.slideUp();
#                         link_1491886632[0].innerHTML = "Show Input";
#                     }
#                 }
#             }
#         }());
#         </script>

# %% [markdown]
# We can drive these neurons with our input signal
# and observe their spiking activity over time.

# %%
with model:
    nengo.Connection(input, A)
    A_spikes = nengo.Probe(A.neurons)

# %%
with nengo.Simulator(model) as sim:
    sim.run(1)

plt.figure()
ax = plt.subplot(1, 1, 1)
rasterplot(sim.trange(), sim.data[A_spikes], ax)
ax.set_xlim(0, 1)
ax.set_ylabel('Neuron')
ax.set_xlabel('Time (s)');
hide_input()
# Out:
#         <a id="1424593176" href="javascript:toggle_input_1424593176()"
#           >Show Input</a>
#
#         <script type="text/javascript">
#         var toggle_input_1424593176;
#         (function() {
#             if (typeof jQuery == 'undefined') {
#                 // no jQuery
#                 var link_1424593176 = document.getElementById("1424593176");
#                 var cell = link_1424593176;
#                 while (cell.className.split(' ')[0] != "cell"
#                        && cell.className.split(' ')[0] != "nboutput") {
#                     cell = cell.parentNode;
#                 }
#                 var input_1424593176;
#                 if (cell.className.split(' ')[0] == "cell") {
#                     for (var i = 0; i < cell.children.length; i++) {
#                         if (cell.children[i].className.split(' ')[0]
#                             == "input") {
#                             input_1424593176 = cell.children[i];
#                         }
#                     }
#                 } else {
#                     input_1424593176 = cell.previousElementSibling;
#                 }
#                 input_1424593176.style.display = "none"; // hide
#
#                 toggle_input_1424593176 = function() {
#                     if (input_1424593176.style.display == "none") {
#                         input_1424593176.style.display = ""; // show
#                         link_1424593176.innerHTML = "Hide Input";
#                     } else {
#                         input_1424593176.style.display = "none"; // hide
#                         link_1424593176.innerHTML = "Show Input";
#                     }
#                 }
#
#             } else {
#                 // jQuery
#                 var link_1424593176 = $("a[id='1424593176']");
#                 var cell_1424593176 = link_1424593176.parents("div.cell:first");
#                 if (cell_1424593176.length == 0) {
#                     cell_1424593176 = link_1424593176.parents(
#                         "div.nboutput:first");
#                 }
#                 var input_1424593176 = cell_1424593176.children("div.input");
#                 if (input_1424593176.length == 0) {
#                     input_1424593176 = cell_1424593176.prev("div.nbinput");
#                 }
#                 input_1424593176.hide();
#
#                 toggle_input_1424593176 = function() {
#                     if (input_1424593176.is(':hidden')) {
#                         input_1424593176.slideDown();
#                         link_1424593176[0].innerHTML = "Hide Input";
#                     } else {
#                         input_1424593176.slideUp();
#                         link_1424593176[0].innerHTML = "Show Input";
#                     }
#                 }
#             }
#         }());
#         </script>

# %% [markdown]
# ### Decoding
#
# We can estimate the input signal
# originally encoded by decoding the pattern of spikes.
# To do this, we first filter the spike train
# with a temporal filter that accounts for
# postsynaptic current (PSC) activity.

# %%
model = nengo.Network(label="NEF summary")
with model:
    input = nengo.Node(lambda t: t * 2 - 1)
    input_probe = nengo.Probe(input)
    intercepts, encoders = aligned(8)  # Makes evenly spaced intercepts
    A = nengo.Ensemble(8, dimensions=1,
                       intercepts=intercepts,
                       max_rates=Uniform(80, 100),
                       encoders=encoders)
    nengo.Connection(input, A)
    A_spikes = nengo.Probe(A.neurons, synapse=0.01)

# %%
with nengo.Simulator(model) as sim:
    sim.run(1)

scale = 180
plt.figure()
for i in range(A.n_neurons):
    plt.plot(sim.trange(), sim.data[A_spikes][:, i] - i * scale)
plt.xlim(0, 1)
plt.ylim(scale * (-A.n_neurons + 1), scale)
plt.ylabel("Neuron")
plt.yticks(
    np.arange(scale / 1.8, (-A.n_neurons + 1) * scale, -scale),
    np.arange(A.n_neurons))
hide_input()
# Out:
#         <a id="1951932227" href="javascript:toggle_input_1951932227()"
#           >Show Input</a>
#
#         <script type="text/javascript">
#         var toggle_input_1951932227;
#         (function() {
#             if (typeof jQuery == 'undefined') {
#                 // no jQuery
#                 var link_1951932227 = document.getElementById("1951932227");
#                 var cell = link_1951932227;
#                 while (cell.className.split(' ')[0] != "cell"
#                        && cell.className.split(' ')[0] != "nboutput") {
#                     cell = cell.parentNode;
#                 }
#                 var input_1951932227;
#                 if (cell.className.split(' ')[0] == "cell") {
#                     for (var i = 0; i < cell.children.length; i++) {
#                         if (cell.children[i].className.split(' ')[0]
#                             == "input") {
#                             input_1951932227 = cell.children[i];
#                         }
#                     }
#                 } else {
#                     input_1951932227 = cell.previousElementSibling;
#                 }
#                 input_1951932227.style.display = "none"; // hide
#
#                 toggle_input_1951932227 = function() {
#                     if (input_1951932227.style.display == "none") {
#                         input_1951932227.style.display = ""; // show
#                         link_1951932227.innerHTML = "Hide Input";
#                     } else {
#                         input_1951932227.style.display = "none"; // hide
#                         link_1951932227.innerHTML = "Show Input";
#                     }
#                 }
#
#             } else {
#                 // jQuery
#                 var link_1951932227 = $("a[id='1951932227']");
#                 var cell_1951932227 = link_1951932227.parents("div.cell:first");
#                 if (cell_1951932227.length == 0) {
#                     cell_1951932227 = link_1951932227.parents(
#                         "div.nboutput:first");
#                 }
#                 var input_1951932227 = cell_1951932227.children("div.input");
#                 if (input_1951932227.length == 0) {
#                     input_1951932227 = cell_1951932227.prev("div.nbinput");
#                 }
#                 input_1951932227.hide();
#
#                 toggle_input_1951932227 = function() {
#                     if (input_1951932227.is(':hidden')) {
#                         input_1951932227.slideDown();
#                         link_1951932227[0].innerHTML = "Hide Input";
#                     } else {
#                         input_1951932227.slideUp();
#                         link_1951932227[0].innerHTML = "Show Input";
#                     }
#                 }
#             }
#         }());
#         </script>

# %% [markdown]
# Then we mulitply those filtered spike trains
# with decoding weights and sum them together
# to give an estimate of the input based on the spikes.
#
# The decoding weights are determined
# by minimizing the squared difference
# between the decoded estimate and the actual input signal.

# %%
with model:
    A_probe = nengo.Probe(A, synapse=0.01)  # 10ms PSC filter

# %%
with nengo.Simulator(model) as sim:
    sim.run(1)

plt.figure()
plt.plot(sim.trange(), sim.data[input_probe], label="Input signal")
plt.plot(sim.trange(), sim.data[A_probe], label="Decoded estimate")
plt.legend(loc="best")
plt.xlim(0, 1)
hide_input()
# Out:
#         <a id="1484301552" href="javascript:toggle_input_1484301552()"
#           >Show Input</a>
#
#         <script type="text/javascript">
#         var toggle_input_1484301552;
#         (function() {
#             if (typeof jQuery == 'undefined') {
#                 // no jQuery
#                 var link_1484301552 = document.getElementById("1484301552");
#                 var cell = link_1484301552;
#                 while (cell.className.split(' ')[0] != "cell"
#                        && cell.className.split(' ')[0] != "nboutput") {
#                     cell = cell.parentNode;
#                 }
#                 var input_1484301552;
#                 if (cell.className.split(' ')[0] == "cell") {
#                     for (var i = 0; i < cell.children.length; i++) {
#                         if (cell.children[i].className.split(' ')[0]
#                             == "input") {
#                             input_1484301552 = cell.children[i];
#                         }
#                     }
#                 } else {
#                     input_1484301552 = cell.previousElementSibling;
#                 }
#                 input_1484301552.style.display = "none"; // hide
#
#                 toggle_input_1484301552 = function() {
#                     if (input_1484301552.style.display == "none") {
#                         input_1484301552.style.display = ""; // show
#                         link_1484301552.innerHTML = "Hide Input";
#                     } else {
#                         input_1484301552.style.display = "none"; // hide
#                         link_1484301552.innerHTML = "Show Input";
#                     }
#                 }
#
#             } else {
#                 // jQuery
#                 var link_1484301552 = $("a[id='1484301552']");
#                 var cell_1484301552 = link_1484301552.parents("div.cell:first");
#                 if (cell_1484301552.length == 0) {
#                     cell_1484301552 = link_1484301552.parents(
#                         "div.nboutput:first");
#                 }
#                 var input_1484301552 = cell_1484301552.children("div.input");
#                 if (input_1484301552.length == 0) {
#                     input_1484301552 = cell_1484301552.prev("div.nbinput");
#                 }
#                 input_1484301552.hide();
#
#                 toggle_input_1484301552 = function() {
#                     if (input_1484301552.is(':hidden')) {
#                         input_1484301552.slideDown();
#                         link_1484301552[0].innerHTML = "Hide Input";
#                     } else {
#                         input_1484301552.slideUp();
#                         link_1484301552[0].innerHTML = "Show Input";
#                     }
#                 }
#             }
#         }());
#         </script>

# %% [markdown]
# The accuracy of the decoded estimate increases
# as the number of neurons increases.

# %%
model = nengo.Network(label="NEF summary")
with model:
    input = nengo.Node(lambda t: t * 2 - 1)
    input_probe = nengo.Probe(input)
    A = nengo.Ensemble(30, dimensions=1, max_rates=Uniform(80, 100))
    nengo.Connection(input, A)
    A_spikes = nengo.Probe(A.neurons)
    A_probe = nengo.Probe(A, synapse=0.01)

# %%
with nengo.Simulator(model) as sim:
    sim.run(1)

plt.figure(figsize=(15, 3.5))

plt.subplot(1, 3, 1)
eval_points, activities = tuning_curves(A, sim)
plt.plot(eval_points, activities, lw=2)
plt.xlabel("Input signal")
plt.ylabel("Firing rate (Hz)")

ax = plt.subplot(1, 3, 2)
rasterplot(sim.trange(), sim.data[A_spikes], ax)
plt.xlim(0, 1)
plt.xlabel("Time (s)")
plt.ylabel("Neuron")

plt.subplot(1, 3, 3)
plt.plot(sim.trange(), sim.data[input_probe], label="Input signal")
plt.plot(sim.trange(), sim.data[A_probe], label="Decoded esimate")
plt.legend(loc="best")
plt.xlabel("Time (s)")
plt.xlim(0, 1)
hide_input()
# Out:
#         <a id="1973269014" href="javascript:toggle_input_1973269014()"
#           >Show Input</a>
#
#         <script type="text/javascript">
#         var toggle_input_1973269014;
#         (function() {
#             if (typeof jQuery == 'undefined') {
#                 // no jQuery
#                 var link_1973269014 = document.getElementById("1973269014");
#                 var cell = link_1973269014;
#                 while (cell.className.split(' ')[0] != "cell"
#                        && cell.className.split(' ')[0] != "nboutput") {
#                     cell = cell.parentNode;
#                 }
#                 var input_1973269014;
#                 if (cell.className.split(' ')[0] == "cell") {
#                     for (var i = 0; i < cell.children.length; i++) {
#                         if (cell.children[i].className.split(' ')[0]
#                             == "input") {
#                             input_1973269014 = cell.children[i];
#                         }
#                     }
#                 } else {
#                     input_1973269014 = cell.previousElementSibling;
#                 }
#                 input_1973269014.style.display = "none"; // hide
#
#                 toggle_input_1973269014 = function() {
#                     if (input_1973269014.style.display == "none") {
#                         input_1973269014.style.display = ""; // show
#                         link_1973269014.innerHTML = "Hide Input";
#                     } else {
#                         input_1973269014.style.display = "none"; // hide
#                         link_1973269014.innerHTML = "Show Input";
#                     }
#                 }
#
#             } else {
#                 // jQuery
#                 var link_1973269014 = $("a[id='1973269014']");
#                 var cell_1973269014 = link_1973269014.parents("div.cell:first");
#                 if (cell_1973269014.length == 0) {
#                     cell_1973269014 = link_1973269014.parents(
#                         "div.nboutput:first");
#                 }
#                 var input_1973269014 = cell_1973269014.children("div.input");
#                 if (input_1973269014.length == 0) {
#                     input_1973269014 = cell_1973269014.prev("div.nbinput");
#                 }
#                 input_1973269014.hide();
#
#                 toggle_input_1973269014 = function() {
#                     if (input_1973269014.is(':hidden')) {
#                         input_1973269014.slideDown();
#                         link_1973269014[0].innerHTML = "Hide Input";
#                     } else {
#                         input_1973269014.slideUp();
#                         link_1973269014[0].innerHTML = "Show Input";
#                     }
#                 }
#             }
#         }());
#         </script>

# %% [markdown]
# Any smooth signal can be encoded and decoded.

# %%
model = nengo.Network(label="NEF summary")
with model:
    input = nengo.Node(WhiteSignal(1, high=5), size_out=1)
    input_probe = nengo.Probe(input)
    A = nengo.Ensemble(30, dimensions=1, max_rates=Uniform(80, 100))
    nengo.Connection(input, A)
    A_spikes = nengo.Probe(A.neurons)
    A_probe = nengo.Probe(A, synapse=0.01)

# %%
with nengo.Simulator(model) as sim:
    sim.run(1)

plt.figure(figsize=(10, 3.5))
plt.subplot(1, 2, 1)
plt.plot(sim.trange(), sim.data[input_probe], label="Input signal")
plt.plot(sim.trange(), sim.data[A_probe], label="Decoded esimate")
plt.legend(loc="best")
plt.xlabel("Time (s)")
plt.xlim(0, 1)

ax = plt.subplot(1, 2, 2)
rasterplot(sim.trange(), sim.data[A_spikes], ax)
plt.xlim(0, 1)
plt.xlabel("Time (s)")
plt.ylabel("Neuron")
hide_input()
# Out:
#         <a id="1669408796" href="javascript:toggle_input_1669408796()"
#           >Show Input</a>
#
#         <script type="text/javascript">
#         var toggle_input_1669408796;
#         (function() {
#             if (typeof jQuery == 'undefined') {
#                 // no jQuery
#                 var link_1669408796 = document.getElementById("1669408796");
#                 var cell = link_1669408796;
#                 while (cell.className.split(' ')[0] != "cell"
#                        && cell.className.split(' ')[0] != "nboutput") {
#                     cell = cell.parentNode;
#                 }
#                 var input_1669408796;
#                 if (cell.className.split(' ')[0] == "cell") {
#                     for (var i = 0; i < cell.children.length; i++) {
#                         if (cell.children[i].className.split(' ')[0]
#                             == "input") {
#                             input_1669408796 = cell.children[i];
#                         }
#                     }
#                 } else {
#                     input_1669408796 = cell.previousElementSibling;
#                 }
#                 input_1669408796.style.display = "none"; // hide
#
#                 toggle_input_1669408796 = function() {
#                     if (input_1669408796.style.display == "none") {
#                         input_1669408796.style.display = ""; // show
#                         link_1669408796.innerHTML = "Hide Input";
#                     } else {
#                         input_1669408796.style.display = "none"; // hide
#                         link_1669408796.innerHTML = "Show Input";
#                     }
#                 }
#
#             } else {
#                 // jQuery
#                 var link_1669408796 = $("a[id='1669408796']");
#                 var cell_1669408796 = link_1669408796.parents("div.cell:first");
#                 if (cell_1669408796.length == 0) {
#                     cell_1669408796 = link_1669408796.parents(
#                         "div.nboutput:first");
#                 }
#                 var input_1669408796 = cell_1669408796.children("div.input");
#                 if (input_1669408796.length == 0) {
#                     input_1669408796 = cell_1669408796.prev("div.nbinput");
#                 }
#                 input_1669408796.hide();
#
#                 toggle_input_1669408796 = function() {
#                     if (input_1669408796.is(':hidden')) {
#                         input_1669408796.slideDown();
#                         link_1669408796[0].innerHTML = "Hide Input";
#                     } else {
#                         input_1669408796.slideUp();
#                         link_1669408796[0].innerHTML = "Show Input";
#                     }
#                 }
#             }
#         }());
#         </script>

# %% [markdown]
# ## Principle 2: Transformation
#
# Encoding and decoding allow us to encode signals over time,
# and decode transformations of those signals.
#
# In fact, we can decode arbitrary transformations of the input signal,
# not just the signal itself (as in the previous example).
#
# Let's decode the square of our white noise input.

# %%
model = nengo.Network(label="NEF summary")
with model:
    input = nengo.Node(WhiteSignal(1, high=5), size_out=1)
    input_probe = nengo.Probe(input, )
    A = nengo.Ensemble(30, dimensions=1, max_rates=Uniform(80, 100))
    Asquare = nengo.Node(size_in=1)
    nengo.Connection(input, A)
    nengo.Connection(A, Asquare, function=np.square)
    A_spikes = nengo.Probe(A.neurons)
    Asquare_probe = nengo.Probe(Asquare, synapse=0.01)

# %%
with nengo.Simulator(model) as sim:
    sim.run(1)

plt.figure(figsize=(10, 3.5))
plt.subplot(1, 2, 1)
plt.plot(
    sim.trange(),
    sim.data[input_probe],
    label="Input signal")
plt.plot(
    sim.trange(),
    sim.data[Asquare_probe],
    label="Decoded esimate")
plt.plot(
    sim.trange(),
    np.square(sim.data[input_probe]),
    label="Input signal squared")
plt.legend(loc="best", fontsize='medium')
plt.xlabel("Time (s)")
plt.xlim(0, 1)

ax = plt.subplot(1, 2, 2)
rasterplot(sim.trange(), sim.data[A_spikes])
plt.xlim(0, 1)
plt.xlabel("Time (s)")
plt.ylabel("Neuron")
hide_input()
# Out:
#         <a id="1830166369" href="javascript:toggle_input_1830166369()"
#           >Show Input</a>
#
#         <script type="text/javascript">
#         var toggle_input_1830166369;
#         (function() {
#             if (typeof jQuery == 'undefined') {
#                 // no jQuery
#                 var link_1830166369 = document.getElementById("1830166369");
#                 var cell = link_1830166369;
#                 while (cell.className.split(' ')[0] != "cell"
#                        && cell.className.split(' ')[0] != "nboutput") {
#                     cell = cell.parentNode;
#                 }
#                 var input_1830166369;
#                 if (cell.className.split(' ')[0] == "cell") {
#                     for (var i = 0; i < cell.children.length; i++) {
#                         if (cell.children[i].className.split(' ')[0]
#                             == "input") {
#                             input_1830166369 = cell.children[i];
#                         }
#                     }
#                 } else {
#                     input_1830166369 = cell.previousElementSibling;
#                 }
#                 input_1830166369.style.display = "none"; // hide
#
#                 toggle_input_1830166369 = function() {
#                     if (input_1830166369.style.display == "none") {
#                         input_1830166369.style.display = ""; // show
#                         link_1830166369.innerHTML = "Hide Input";
#                     } else {
#                         input_1830166369.style.display = "none"; // hide
#                         link_1830166369.innerHTML = "Show Input";
#                     }
#                 }
#
#             } else {
#                 // jQuery
#                 var link_1830166369 = $("a[id='1830166369']");
#                 var cell_1830166369 = link_1830166369.parents("div.cell:first");
#                 if (cell_1830166369.length == 0) {
#                     cell_1830166369 = link_1830166369.parents(
#                         "div.nboutput:first");
#                 }
#                 var input_1830166369 = cell_1830166369.children("div.input");
#                 if (input_1830166369.length == 0) {
#                     input_1830166369 = cell_1830166369.prev("div.nbinput");
#                 }
#                 input_1830166369.hide();
#
#                 toggle_input_1830166369 = function() {
#                     if (input_1830166369.is(':hidden')) {
#                         input_1830166369.slideDown();
#                         link_1830166369[0].innerHTML = "Hide Input";
#                     } else {
#                         input_1830166369.slideUp();
#                         link_1830166369[0].innerHTML = "Show Input";
#                     }
#                 }
#             }
#         }());
#         </script>

# %% [markdown]
# Notice that the spike trains are exactly the same.
# The only difference is how we're interpreting those spikes.
# We told Nengo to compute a new set of decoders
# that estimate the function $x^2$.
#
# In general, the transformation principle
# determines how we can decode spike trains
# to compute linear and nonlinear transformations of signals
# encoded in a population of neurons.
# We can then project those transformed signals
# into another population, and repeat the process.
# Essentially, this provides a means of
# computing the neural connection weights
# to compute an arbitrary function between populations.
#
# Suppose we are representing a sine wave.

# %%
model = nengo.Network(label="NEF summary")
with model:
    input = nengo.Node(lambda t: np.sin(np.pi * t))
    A = nengo.Ensemble(30, dimensions=1, max_rates=Uniform(80, 100))
    nengo.Connection(input, A)
    A_spikes = nengo.Probe(A.neurons)
    A_probe = nengo.Probe(A, synapse=0.01)

# %%
with nengo.Simulator(model) as sim:
    sim.run(2)

plt.figure(figsize=(10, 3.5))
plt.subplot(1, 2, 1)
plt.plot(sim.trange(), sim.data[A_probe])
plt.title("A")
plt.xlabel("Time (s)")
plt.xlim(0, 2)

ax = plt.subplot(1, 2, 2)
rasterplot(sim.trange(), sim.data[A_spikes], ax)
plt.xlim(0, 2)
plt.title("A")
plt.xlabel("Time (s)")
plt.ylabel("Neuron")
hide_input()
# Out:
#         <a id="1146463217" href="javascript:toggle_input_1146463217()"
#           >Show Input</a>
#
#         <script type="text/javascript">
#         var toggle_input_1146463217;
#         (function() {
#             if (typeof jQuery == 'undefined') {
#                 // no jQuery
#                 var link_1146463217 = document.getElementById("1146463217");
#                 var cell = link_1146463217;
#                 while (cell.className.split(' ')[0] != "cell"
#                        && cell.className.split(' ')[0] != "nboutput") {
#                     cell = cell.parentNode;
#                 }
#                 var input_1146463217;
#                 if (cell.className.split(' ')[0] == "cell") {
#                     for (var i = 0; i < cell.children.length; i++) {
#                         if (cell.children[i].className.split(' ')[0]
#                             == "input") {
#                             input_1146463217 = cell.children[i];
#                         }
#                     }
#                 } else {
#                     input_1146463217 = cell.previousElementSibling;
#                 }
#                 input_1146463217.style.display = "none"; // hide
#
#                 toggle_input_1146463217 = function() {
#                     if (input_1146463217.style.display == "none") {
#                         input_1146463217.style.display = ""; // show
#                         link_1146463217.innerHTML = "Hide Input";
#                     } else {
#                         input_1146463217.style.display = "none"; // hide
#                         link_1146463217.innerHTML = "Show Input";
#                     }
#                 }
#
#             } else {
#                 // jQuery
#                 var link_1146463217 = $("a[id='1146463217']");
#                 var cell_1146463217 = link_1146463217.parents("div.cell:first");
#                 if (cell_1146463217.length == 0) {
#                     cell_1146463217 = link_1146463217.parents(
#                         "div.nboutput:first");
#                 }
#                 var input_1146463217 = cell_1146463217.children("div.input");
#                 if (input_1146463217.length == 0) {
#                     input_1146463217 = cell_1146463217.prev("div.nbinput");
#                 }
#                 input_1146463217.hide();
#
#                 toggle_input_1146463217 = function() {
#                     if (input_1146463217.is(':hidden')) {
#                         input_1146463217.slideDown();
#                         link_1146463217[0].innerHTML = "Hide Input";
#                     } else {
#                         input_1146463217.slideUp();
#                         link_1146463217[0].innerHTML = "Show Input";
#                     }
#                 }
#             }
#         }());
#         </script>

# %% [markdown]
# Linear transformations of that signal
# involve solving for the usual decoders,
# and scaling those decoding weights.
# Let us flip this sine wave upside down
# as it is transmitted between two populations
# (i.e. population A and population -A).

# %%
with model:
    minusA = nengo.Ensemble(30, dimensions=1, max_rates=Uniform(80, 100))
    nengo.Connection(A, minusA, function=lambda x: -x)
    minusA_spikes = nengo.Probe(minusA.neurons)
    minusA_probe = nengo.Probe(minusA, synapse=0.01)

# %%
with nengo.Simulator(model) as sim:
    sim.run(2)

plt.figure(figsize=(10, 5))
plt.subplot(2, 2, 1)
plt.plot(sim.trange(), sim.data[A_probe])
plt.title("A")
plt.xticks(())
plt.xlim(0, 2)

plt.subplot(2, 2, 3)
plt.plot(sim.trange(), sim.data[minusA_probe])
plt.title("-A")
plt.xlabel("Time (s)")
plt.xlim(0, 2)

ax = plt.subplot(2, 2, 2)
rasterplot(sim.trange(), sim.data[A_spikes], ax)
plt.xlim(0, 2)
plt.title("A")
plt.xticks(())
plt.ylabel("Neuron")

ax = plt.subplot(2, 2, 4)
rasterplot(sim.trange(), sim.data[minusA_spikes], ax)
plt.xlim(0, 2)
plt.title("-A")
plt.xlabel("Time (s)")
plt.ylabel("Neuron")
hide_input()
# Out:
#         <a id="2137309838" href="javascript:toggle_input_2137309838()"
#           >Show Input</a>
#
#         <script type="text/javascript">
#         var toggle_input_2137309838;
#         (function() {
#             if (typeof jQuery == 'undefined') {
#                 // no jQuery
#                 var link_2137309838 = document.getElementById("2137309838");
#                 var cell = link_2137309838;
#                 while (cell.className.split(' ')[0] != "cell"
#                        && cell.className.split(' ')[0] != "nboutput") {
#                     cell = cell.parentNode;
#                 }
#                 var input_2137309838;
#                 if (cell.className.split(' ')[0] == "cell") {
#                     for (var i = 0; i < cell.children.length; i++) {
#                         if (cell.children[i].className.split(' ')[0]
#                             == "input") {
#                             input_2137309838 = cell.children[i];
#                         }
#                     }
#                 } else {
#                     input_2137309838 = cell.previousElementSibling;
#                 }
#                 input_2137309838.style.display = "none"; // hide
#
#                 toggle_input_2137309838 = function() {
#                     if (input_2137309838.style.display == "none") {
#                         input_2137309838.style.display = ""; // show
#                         link_2137309838.innerHTML = "Hide Input";
#                     } else {
#                         input_2137309838.style.display = "none"; // hide
#                         link_2137309838.innerHTML = "Show Input";
#                     }
#                 }
#
#             } else {
#                 // jQuery
#                 var link_2137309838 = $("a[id='2137309838']");
#                 var cell_2137309838 = link_2137309838.parents("div.cell:first");
#                 if (cell_2137309838.length == 0) {
#                     cell_2137309838 = link_2137309838.parents(
#                         "div.nboutput:first");
#                 }
#                 var input_2137309838 = cell_2137309838.children("div.input");
#                 if (input_2137309838.length == 0) {
#                     input_2137309838 = cell_2137309838.prev("div.nbinput");
#                 }
#                 input_2137309838.hide();
#
#                 toggle_input_2137309838 = function() {
#                     if (input_2137309838.is(':hidden')) {
#                         input_2137309838.slideDown();
#                         link_2137309838[0].innerHTML = "Hide Input";
#                     } else {
#                         input_2137309838.slideUp();
#                         link_2137309838[0].innerHTML = "Show Input";
#                     }
#                 }
#             }
#         }());
#         </script>

# %% [markdown]
# Nonlinear transformations involve
# solving for a new set of decoding weights.
# Let us add a third population connected
# to the second one and use it to compute $(-A)^2$.

# %%
with model:
    A_squared = nengo.Ensemble(30, dimensions=1, max_rates=Uniform(80, 100))
    nengo.Connection(minusA, A_squared, function=lambda x: x ** 2)
    A_squared_spikes = nengo.Probe(A_squared.neurons)
    A_squared_probe = nengo.Probe(A_squared, synapse=0.02)

# %%
with nengo.Simulator(model) as sim:
    sim.run(2)

plt.figure(figsize=(10, 6.5))
plt.subplot(3, 2, 1)
plt.plot(sim.trange(), sim.data[A_probe])
plt.axhline(0, color='k')
plt.title("A")
plt.xticks(())
plt.xlim(0, 2)

plt.subplot(3, 2, 3)
plt.plot(sim.trange(), sim.data[minusA_probe])
plt.axhline(0, color='k')
plt.title("-A")
plt.xticks(())
plt.xlim(0, 2)

plt.subplot(3, 2, 5)
plt.plot(sim.trange(), sim.data[A_squared_probe])
plt.axhline(0, color='k')
plt.title("(-A)^2")
plt.xlabel("Time (s)")
plt.xlim(0, 2)

ax = plt.subplot(3, 2, 2)
rasterplot(sim.trange(), sim.data[A_spikes], ax)
plt.xlim(0, 2)
plt.title("A")
plt.xticks(())
plt.ylabel("Neuron")

ax = plt.subplot(3, 2, 4)
rasterplot(sim.trange(), sim.data[minusA_spikes], ax)
plt.xlim(0, 2)
plt.title("-A")
plt.xticks(())
plt.ylabel("Neuron")

ax = plt.subplot(3, 2, 6)
rasterplot(sim.trange(), sim.data[A_squared_spikes], ax)
plt.xlim(0, 2)
plt.title("(-A)^2")
plt.xlabel("Time (s)")
plt.ylabel("Neuron")
hide_input()
# Out:
#         <a id="352706964" href="javascript:toggle_input_352706964()"
#           >Show Input</a>
#
#         <script type="text/javascript">
#         var toggle_input_352706964;
#         (function() {
#             if (typeof jQuery == 'undefined') {
#                 // no jQuery
#                 var link_352706964 = document.getElementById("352706964");
#                 var cell = link_352706964;
#                 while (cell.className.split(' ')[0] != "cell"
#                        && cell.className.split(' ')[0] != "nboutput") {
#                     cell = cell.parentNode;
#                 }
#                 var input_352706964;
#                 if (cell.className.split(' ')[0] == "cell") {
#                     for (var i = 0; i < cell.children.length; i++) {
#                         if (cell.children[i].className.split(' ')[0]
#                             == "input") {
#                             input_352706964 = cell.children[i];
#                         }
#                     }
#                 } else {
#                     input_352706964 = cell.previousElementSibling;
#                 }
#                 input_352706964.style.display = "none"; // hide
#
#                 toggle_input_352706964 = function() {
#                     if (input_352706964.style.display == "none") {
#                         input_352706964.style.display = ""; // show
#                         link_352706964.innerHTML = "Hide Input";
#                     } else {
#                         input_352706964.style.display = "none"; // hide
#                         link_352706964.innerHTML = "Show Input";
#                     }
#                 }
#
#             } else {
#                 // jQuery
#                 var link_352706964 = $("a[id='352706964']");
#                 var cell_352706964 = link_352706964.parents("div.cell:first");
#                 if (cell_352706964.length == 0) {
#                     cell_352706964 = link_352706964.parents(
#                         "div.nboutput:first");
#                 }
#                 var input_352706964 = cell_352706964.children("div.input");
#                 if (input_352706964.length == 0) {
#                     input_352706964 = cell_352706964.prev("div.nbinput");
#                 }
#                 input_352706964.hide();
#
#                 toggle_input_352706964 = function() {
#                     if (input_352706964.is(':hidden')) {
#                         input_352706964.slideDown();
#                         link_352706964[0].innerHTML = "Hide Input";
#                     } else {
#                         input_352706964.slideUp();
#                         link_352706964[0].innerHTML = "Show Input";
#                     }
#                 }
#             }
#         }());
#         </script>

# %% [markdown]
# ## Principle 3: Dynamics
#
# So far, we have been considering the values
# represented by ensembles as generic "signals."
# However, if we think of them instead
# as state variables in a dynamical system,
# then we can apply the methods of control theory
# or dynamic systems theory to brain models.
# Nengo automatically translates from standard dynamical systems descriptions
# to descriptions consistent with neural dynamics.
#
# In order to get interesting dynamics,
# we can connect populations recurrently (i.e., to themselves).
#
# Below is a simple harmonic oscillator
# implemented using this third principle.
# It needs is a bit of input to get it started.

# %%
model = nengo.Network(label="NEF summary")
with model:
    input = nengo.Node(lambda t: [1, 0] if t < 0.1 else [0, 0])
    oscillator = nengo.Ensemble(200, dimensions=2)
    nengo.Connection(input, oscillator)
    nengo.Connection(
        oscillator, oscillator, transform=[[1, 1], [-1, 1]], synapse=0.1)
    oscillator_probe = nengo.Probe(oscillator, synapse=0.02)

# %%
with nengo.Simulator(model) as sim:
    sim.run(3)

plt.figure(figsize=(10, 3.5))
plt.subplot(1, 2, 1)
plt.plot(sim.trange(), sim.data[oscillator_probe])
plt.ylim(-1.2, 1.2)
plt.xlabel('Time (s)')

plt.subplot(1, 2, 2)
plt.plot(sim.data[oscillator_probe][:, 0], sim.data[oscillator_probe][:, 1])
plt.grid()
plt.axis([-1.2, 1.2, -1.2, 1.2])
plt.xlabel('$x_1$')
plt.ylabel('$x_2$')
hide_input()
# Out:
#         <a id="1821760772" href="javascript:toggle_input_1821760772()"
#           >Show Input</a>
#
#         <script type="text/javascript">
#         var toggle_input_1821760772;
#         (function() {
#             if (typeof jQuery == 'undefined') {
#                 // no jQuery
#                 var link_1821760772 = document.getElementById("1821760772");
#                 var cell = link_1821760772;
#                 while (cell.className.split(' ')[0] != "cell"
#                        && cell.className.split(' ')[0] != "nboutput") {
#                     cell = cell.parentNode;
#                 }
#                 var input_1821760772;
#                 if (cell.className.split(' ')[0] == "cell") {
#                     for (var i = 0; i < cell.children.length; i++) {
#                         if (cell.children[i].className.split(' ')[0]
#                             == "input") {
#                             input_1821760772 = cell.children[i];
#                         }
#                     }
#                 } else {
#                     input_1821760772 = cell.previousElementSibling;
#                 }
#                 input_1821760772.style.display = "none"; // hide
#
#                 toggle_input_1821760772 = function() {
#                     if (input_1821760772.style.display == "none") {
#                         input_1821760772.style.display = ""; // show
#                         link_1821760772.innerHTML = "Hide Input";
#                     } else {
#                         input_1821760772.style.display = "none"; // hide
#                         link_1821760772.innerHTML = "Show Input";
#                     }
#                 }
#
#             } else {
#                 // jQuery
#                 var link_1821760772 = $("a[id='1821760772']");
#                 var cell_1821760772 = link_1821760772.parents("div.cell:first");
#                 if (cell_1821760772.length == 0) {
#                     cell_1821760772 = link_1821760772.parents(
#                         "div.nboutput:first");
#                 }
#                 var input_1821760772 = cell_1821760772.children("div.input");
#                 if (input_1821760772.length == 0) {
#                     input_1821760772 = cell_1821760772.prev("div.nbinput");
#                 }
#                 input_1821760772.hide();
#
#                 toggle_input_1821760772 = function() {
#                     if (input_1821760772.is(':hidden')) {
#                         input_1821760772.slideDown();
#                         link_1821760772[0].innerHTML = "Hide Input";
#                     } else {
#                         input_1821760772.slideUp();
#                         link_1821760772[0].innerHTML = "Show Input";
#                     }
#                 }
#             }
#         }());
#         </script>
